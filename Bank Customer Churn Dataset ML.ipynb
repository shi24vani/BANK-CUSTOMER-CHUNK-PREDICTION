# %% [markdown]
# <h5> so the aim is to first analyse which type of customers are churning out of the bank, i.e the possible reasons for churning and all and at the end come up with a conclusion that if a new entry is made in the dataset what is the likelihood(approximate) of them churning out of the bank

# %% [markdown]
# <h5>importing the important libraries</h5>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Data Sourcing</h3>

# %%
df=pd.read_csv("Bank Customer Churn Prediction.csv")

# %% [markdown]
# <h5>displaying the first 5 rows of the dataset</h5>

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# <h3>Data Cleaning</h3>

# %% [markdown]
# <h5>Deleting the 'customer_id' column as it is of no use since indexing is already done in the dataframe</h5>

# %%
df.drop("customer_id", axis=1, inplace=True)
df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %% [markdown]
# <h5>number of rows and columns in this dataset.</h5>

# %%
print("rows,columns : ",df.shape)
# Out:
# rows,columns :  (10000, 11)

# %% [markdown]
# <h5>There are 10000 rows and 11 columns</h5>

# %% [markdown]
# <h5>getting the count of non null values in each column and their datatype.</h5>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   country           10000 non-null  object
#  2   gender            10000 non-null  object
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  int64
#  5   balance           10000 non-null  float64
#  6   products_number   10000 non-null  int64
#  7   credit_card       10000 non-null  int64
#  8   active_member     10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
#  10  churn             10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %% [markdown]
# <h5>There are 8 integer type columns, 2 columns of String type, and 2 columns of float type</h5>

# %% [markdown]
# <h5>displaying the number of null values in each column</h5>

# %%
 df.isnull().sum()
# Out:
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
# <h4>there are no null values in the dataset</h4>

# %% [markdown]
# <h4>statistical info about the dataset :</h4>

# %%
df.describe()
# Out:
#        credit_score           age        tenure        balance  \
# count  10000.000000  10000.000000  10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288
# std       96.653299     10.487806      2.892174   62397.405202
# min      350.000000     18.000000      0.000000       0.000000
# 25%      584.000000     32.000000      3.000000       0.000000
# 50%      652.000000     37.000000      5.000000   97198.540000
# 75%      718.000000     44.000000      7.000000  127644.240000
# max      850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# std           0.581654      0.45584       0.499797      57510.492818
# min           1.000000      0.00000       0.000000         11.580000
# ...

# %% [markdown]
# <h5>Getting the info about the column "credit_score"(the data it contains)</h5>

# %%
df['credit_score']
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: credit_score, Length: 10000, dtype: int64

# %%
# BOXPLOT to display the outliers
sns.boxplot(df['credit_score'])
# Out:
# C:\Users\RAJ RANJAN SINGH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='credit_score'>

# %% [markdown]
# <h5>Position of Outliers</h5>

# %%
lower = np.where(df['credit_score'] <= 400)
lower
# Out:
# (array([   7,  942, 1193, 1201, 1405, 1631, 1838, 1962, 2473, 2579, 5285,
#         5494, 6253, 8154, 8723, 8762, 9210, 9356, 9624], dtype=int64),)

# %% [markdown]
# <h5>Dropping the outliers</h5>

# %%
df.drop(lower[0],inplace=True)

# %%
df.shape
# Out:
# (9981, 11)

# %% [markdown]
# <h5>Checking whether the outliers have been Removed or not</h5>

# %%
sns.boxplot(df.credit_score)
# Out:
# C:\Users\RAJ RANJAN SINGH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='credit_score'>

# %% [markdown]
# <h5>Getting the info about the column "age"(the data it contains)</h5>

# %%
df.age
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: age, Length: 9981, dtype: int64

# %% [markdown]
# <h5>checking if there are any outliers in the column 'age'</h5>

# %%
sns.boxplot(df['age'])
# Out:
# C:\Users\RAJ RANJAN SINGH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# <h5>Position of Outliers</h5>

# %%
upper= np.where(df['age']>60)
upper
# Out:
# (array([  41,   43,   57,   84,  103,  157,  180,  229,  233,  242,  251,
#          275,  309,  363,  370,  384,  386,  398,  415,  483,  537,  558,
#          560,  566,  601,  611,  616,  629,  657,  677,  695,  735,  765,
#          768,  806,  810,  822,  858,  883,  887,  920,  927,  946,  950,
#          955,  961,  967,  995, 1007, 1037, 1038, 1053, 1112, 1116, 1190,
#         1201, 1230, 1231, 1242, 1248, 1274, 1281, 1324, 1338, 1383, 1402,
#         1405, 1428, 1434, 1452, 1514, 1538, 1583, 1602, 1609, 1636, 1784,
#         1804, 1851, 1859, 1894, 1897, 1900, 1926, 1973, 1988, 1994, 2004,
#         2031, 2045, 2070, 2086, 2095, 2100, 2146, 2151, 2156, 2236, 2253,
#         2266, 2290, 2293, 2425, 2430, 2450, 2451, 2510, 2511, 2524, 2532,
#         2544, 2589, 2605, 2649, 2660, 2703, 2707, 2750, 2762, 2767, 2768,
#         2771, 2781, 2845, 2867, 2891, 2898, 2915, 2916, 2998, 3023, 3044,
#         3100, 3132, 3156, 3182, 3193, 3219, 3295, 3298, 3301, 3304, 3307,
# ...

# %% [markdown]
# <h5>The age variable has outliers, but these can be treated as the normal values of age because any person can be over 70 or 80 years of age. Also, the 70–90 age group is sparsely populated and participates in opening term deposit accounts, which is why these sets of people fall out of the box plot, but they are not outliers and can be considered as normal values.</h5>

# %% [markdown]
# <h5>Getting the info about the column "balance"(the data it contains)</h5>

# %% [markdown]
# <h5>checking if there are any outliers in the column 'balance'</h5>

# %%
sns.boxplot(df['balance'])
# Out:
# C:\Users\RAJ RANJAN SINGH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='balance'>

# %% [markdown]
# <h5>There are no outliers in this column</h5>

# %% [markdown]
# <h5>checking if there are any outliers in the column 'estimated_salary'</h5>

# %%
sns.boxplot(df['estimated_salary'])
# Out:
# C:\Users\RAJ RANJAN SINGH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='estimated_salary'>

# %% [markdown]
# <h5>There are no outliers in this column</h5>

# %% [markdown]
# <h3>Univariate analysis- Categorical variables
# </h3>

# %% [markdown]
# <h5>Displaying the count plot for categorical columns 'country' and 'gender'
# </h5>

# %%
cols = 4
rows = 1
fig = plt.figure(figsize= (16,6))
all_categs = df.select_dtypes(include='object')
cat_cols = all_categs.columns
for i, col in enumerate(cat_cols):
    
    ax=fig.add_subplot(rows, cols, i+1)
    
    sns.countplot(x=df[col], ax=ax)
    
    plt.xticks(rotation=45, ha='right')
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# <h3>'active_member' column</h3>

# %%
sns.kdeplot(x='active_member', data=df)
# Out:
# <AxesSubplot:xlabel='active_member', ylabel='Density'>

# %%
labels = 'Active', 'Non-Active'
sizes = [df.active_member[df['active_member']==1].count(), df.active_member[df['active_member']==0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.title("Proportion of customer who are active vs non-active", size = 20)
plt.show()

# %% [markdown]
# <h5>51.5% of the customers are active while 48.5% of them are non-active</h5>

# %% [markdown]
# <h3>'credit_card' column</h3>

# %%
df.credit_card.value_counts()
# Out:
# 1    7039
# 0    2942
# Name: credit_card, dtype: int64

# %% [markdown]
# <h4>The total number of people having credit cards are 7039
#     The total number of people not having credit cards are 2942
# </h4>

# %%
df.credit_card.value_counts().plot.bar()
plt.show()

# %% [markdown]
# <h3>'Gender' Column
# </h3>

# %%
df.gender.value_counts()
# Out:
# Male      5449
# Female    4532
# Name: gender, dtype: int64

# %% [markdown]
# <h4>The total number of males in the dataset are 5449
#     The total number of females in the dataset are 4532
# </h4>

# %%
df.gender.value_counts().plot.barh()
plt.show()

# %% [markdown]
# <h4>the number of males and females is shown in the form of a horizontal bar graph
# </h4>

# %%
#plotting the number of males and females being churned out of the bank(churn=1)
v=df.loc[df.churn==1,"gender"]
v.value_counts().plot.barh()
plt.show()

# %% [markdown]
# <h4>The number of females being churned out is 1128
# The number of males being churned out is 890</h4>

# %% [markdown]
# <h3>'Country' Column
# </h3>

# %%
df.country.value_counts()
# Out:
# France     5008
# Germany    2503
# Spain      2470
# Name: country, dtype: int64

# %%
df.country.value_counts().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h4>The number of people belonging to :
# France=5008,
# Germany=2503,
# Spain=2470</h4>

# %% [markdown]
# <h3>'Churn' Column
# </h3>

# %%
labels = 'Churned', 'Retained'
sizes = [df.churn[df['churn']==1].count(), df.churn[df['churn']==0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.title("Proportion of customer churned and retained", size = 20)
plt.show()

# %% [markdown]
# <h4>20.2% of the total people are churned whereas 79.8% of them are retained</h4>

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.distplot(df.churn, bins=2)
plt.show()
# Out:
# C:\Users\RAJ RANJAN SINGH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <h4>the bar on the right shows the number of customers churned by bank, whereas the bar on the left shows the number of customers that weren't churned by the Bank.</h4>

# %% [markdown]
# <h3>Univariate analysis- Numerical variables
# </h3>

# %%
cols = 3
rows = 3
num_cols = df.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):
#for i in num_cols:    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.histplot(x = df[col], ax = ax)
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# <h3>'tenure' column</h3>

# %%
sns.histplot(x='tenure', data=df)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Count'>

# %%
lower=np.where(df['balance']<1000)
lower
# Out:
# (array([   0,    3,    6, ..., 9975, 9976, 9978], dtype=int64),)

# %% [markdown]
# <h3>'balance' column</h3>

# %%
sns.rugplot(x='balance', data=df, height=.03, color='darkblue')
sns.histplot(x='balance', data=df, kde=True)
# Out:
# <AxesSubplot:xlabel='balance', ylabel='Count'>

# %% [markdown]
# <h3>'age' column</h3>

# %%
sns.violinplot(x=df["age"])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df.age.describe()
# Out:
# count    9981.000000
# mean       38.912634
# std        10.487887
# min        18.000000
# 25%        32.000000
# 50%        37.000000
# 75%        44.000000
# max        92.000000
# Name: age, dtype: float64

# %% [markdown]
# <h3>'credit_score' column</h3>

# %%
# 6. STRIP PLOT
sns.stripplot(x=df["credit_score"])
# Out:
# <AxesSubplot:xlabel='credit_score'>

# %% [markdown]
# <h3>Bivariate Analysis
# </h3>

# %% [markdown]
# <h3>Estimated_salary vs Balance</h3>

# %%
plt.scatter(df['balance'],df['estimated_salary'])

# %% [markdown]
# <h3>Age vs Balance</h3>

# %%
plt.scatter(df.age,df.balance)
plt.show()

# %% [markdown]
# <h4>the customers of lower age groups(i.e. 25 to 50) have a higher balance in their bank accounts.</h4>

# %%
sns.pairplot(data=df, vars=['estimated_salary','age','balance'])

# %% [markdown]
# <h5>Checking the correlation of the columns with each other</h5>

# %%
corr = df.corr() # how are the columns related to each other or dependent on each other
sns.set(rc={'figure.figsize': (8,5)}) 

# Plotting the heatmap of correlation between features
sns.heatmap(corr, annot=True, cmap='plasma')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h4>the column 'churn' is correlated to column 'age', and slightly correlated to column 'balance'
# </h4>

# %% [markdown]
# <h3>churn vs age
# </h3>

# %%
sns.boxplot(data=df,x="churn",y="age")
plt.show()

# %% [markdown]
# <h4>People of higher age group i.e. age>45 are more likely to be churned/removed by the bank
# </h4>

# %% [markdown]
# <h5> checking the correlation of different columns with each other

# %%
df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
#splitting the data into training and testing data in 80:20 ratio
df_train = df.sample(frac=0.8,random_state=200)
df_test = df.drop(df_train.index)
print(len(df_train))
print(len(df_test))
# Out:
# 7985
# 1996

# %%
# Given that tenure is a 'function' of age, we introduce a variable aiming to standardize tenure over age:
df_train['TenureByAge'] = df_train.tenure/(df_train.age)
sns.boxplot(y='TenureByAge',x = 'churn', hue = 'churn',data = df_train)
plt.ylim(-1, 1)
plt.show()

# %%
'''Lastly we introduce a variable to capture credit score given age to take into account credit behaviour visavis adult life
'''
df_train['CreditScoreGivenAge'] = df_train.credit_score/(df_train.age)

# %%
df_train['BalanceSalaryRatio'] = df_train.balance/df_train.estimated_salary
sns.boxplot(y='BalanceSalaryRatio',x = 'churn', hue = 'churn',data = df_train)
plt.ylim(-1, 5)
# Out:
# (-1.0, 5.0)

# %%
# Resulting Data Frame
df_train.head()
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 7838           569  Germany  Female   32       8  145330.43                1
# 8123           711   France    Male   33       1       0.00                1
# 3478           537   France    Male   28       3  157842.07                1
# 186            730   France  Female   39       1   99010.67                1
# 9229           847  Germany  Female   35       5  111743.43                1
#
#       credit_card  active_member  estimated_salary  churn  TenureByAge  \
# 7838            1              1         132038.65      0     0.250000
# 8123            0              0          41590.40      0     0.030303
# 3478            1              0          86911.49      0     0.107143
# 186             1              0         194945.80      0     0.025641
# 9229            1              1         183584.14      0     0.142857
#
#       CreditScoreGivenAge  BalanceSalaryRatio
# ...

# %%
# Arranging columns by data type for easier manipulation
continuous_vars = ['credit_score',  'age', 'tenure', 'balance','products_number', 'estimated_salary', 'BalanceSalaryRatio',
                   'TenureByAge','CreditScoreGivenAge']
cat_vars = ['credit_card', 'active_member','country', 'gender']
df_train = df_train[['churn'] + continuous_vars + cat_vars]
df_train.head()
# Out:
#       churn  credit_score  age  tenure    balance  products_number  \
# 7838      0           569   32       8  145330.43                1
# 8123      0           711   33       1       0.00                1
# 3478      0           537   28       3  157842.07                1
# 186       0           730   39       1   99010.67                1
# 9229      0           847   35       5  111743.43                1
#
#       estimated_salary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 7838         132038.65            1.100666     0.250000            17.781250
# 8123          41590.40            0.000000     0.030303            21.545455
# 3478          86911.49            1.816124     0.107143            19.178571
# 186          194945.80            0.507888     0.025641            18.717949
# 9229         183584.14            0.608677     0.142857            24.200000
#
#       credit_card  active_member  country  gender
# ...

# %%
'''For the one hot variables, we change 0 to -1 so that the models can capture a negative relation 
where the attribute in inapplicable instead of 0'''
df_train.loc[df_train.credit_card == 0, 'credit_card'] = -1
df_train.loc[df_train.active_member == 0, 'active_member'] = -1
df_train.head()
# Out:
#       churn  credit_score  age  tenure    balance  products_number  \
# 7838      0           569   32       8  145330.43                1
# 8123      0           711   33       1       0.00                1
# 3478      0           537   28       3  157842.07                1
# 186       0           730   39       1   99010.67                1
# 9229      0           847   35       5  111743.43                1
#
#       estimated_salary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 7838         132038.65            1.100666     0.250000            17.781250
# 8123          41590.40            0.000000     0.030303            21.545455
# 3478          86911.49            1.816124     0.107143            19.178571
# 186          194945.80            0.507888     0.025641            18.717949
# 9229         183584.14            0.608677     0.142857            24.200000
#
#       credit_card  active_member  country  gender
# ...

# %%
lst = ['country', 'gender']
remove = list()
for i in lst:
    if (df_train[i].dtype == np.str or df_train[i].dtype == np.object):
        for j in df_train[i].unique():
            df_train[i+'_'+j] = np.where(df_train[i] == j,1,-1)
        remove.append(i)
df_train = df_train.drop(remove, axis=1)
df_train.head()
# Out:
# C:\Users\RAJ RANJAN SINGH\AppData\Local\Temp\ipykernel_15336\1939745240.py:4: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if (df_train[i].dtype == np.str or df_train[i].dtype == np.object):
# C:\Users\RAJ RANJAN SINGH\AppData\Local\Temp\ipykernel_15336\1939745240.py:4: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if (df_train[i].dtype == np.str or df_train[i].dtype == np.object):
# ...

# %%
#min-max scaling the continuous variables
minVec = df_train[continuous_vars].min().copy()
maxVec = df_train[continuous_vars].max().copy()
df_train[continuous_vars] = (df_train[continuous_vars]-minVec)/(maxVec-minVec)
df_train.head()
# Out:
#       churn  credit_score       age  tenure   balance  products_number  \
# 7838      0      0.374165  0.189189     0.8  0.579241              0.0
# 8123      0      0.690423  0.202703     0.1  0.000000              0.0
# 3478      0      0.302895  0.135135     0.3  0.629108              0.0
# 186       0      0.732739  0.283784     0.1  0.394625              0.0
# 9229      0      0.993318  0.229730     0.5  0.445374              0.0
#
#       estimated_salary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 7838          0.660407            0.000104     0.450000             0.307484
# 8123          0.207980            0.000000     0.054545             0.397041
# 3478          0.434679            0.000171     0.192857             0.340729
# 186           0.975073            0.000048     0.046154             0.329770
# 9229          0.918241            0.000057     0.257143             0.460196
#
#       credit_card  active_member  country_Germany  country_France  \
# ...

# %%
# Fit models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Scoring functions
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
# Function to give best model score and parameters
def best_model(model):
    print(model.best_score_)    
    print(model.best_params_)
    print(model.best_estimator_)
def get_auc_scores(y_actual, method,method2):
    auc_score = roc_auc_score(y_actual, method); 
    fpr_df, tpr_df, _ = roc_curve(y_actual, method2); 
    return (auc_score, fpr_df, tpr_df)

# %%
# Fit primal logistic regression
param_grid = {'C': [0.1,0.5,1,10,50,100], 'max_iter': [250], 'fit_intercept':[True],'intercept_scaling':[1],
              'penalty':['l2'], 'tol':[0.00001,0.0001,0.000001]}
log_primal_Grid = GridSearchCV(LogisticRegression(solver='lbfgs'),param_grid, cv=10, refit=True, verbose=0)
log_primal_Grid.fit(df_train.loc[:, df_train.columns != 'churn'],df_train.churn)
best_model(log_primal_Grid)
# Out:
# C:\Users\RAJ RANJAN SINGH\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\RAJ RANJAN SINGH\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Fit random forest classifier
param_grid = {'max_depth': [3, 5, 6, 7, 8], 'max_features': [2,4,6,7,8,9],'n_estimators':[50,100],'min_samples_split': [3, 5, 6, 7]}
RanFor_grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, refit=True, verbose=0)
RanFor_grid.fit(df_train.loc[:, df_train.columns != 'churn'],df_train.churn)
best_model(RanFor_grid)
# Out:
# 0.867501565435191
# {'max_depth': 8, 'max_features': 7, 'min_samples_split': 6, 'n_estimators': 50}
# RandomForestClassifier(max_depth=8, max_features=7, min_samples_split=6,
#                        n_estimators=50)

# %% [markdown]
# From the review of the fitted models above, the best model that gives a decent balance of the recall and precision is the random forest where according to the fit on the training set, with a precision score on 1's of 0.88, out of all customers that the model thinks will churn, 88% do actually churn and with the recall score of 0.53 on the 1's, the model is able to highlight 53% of all those who churned.
